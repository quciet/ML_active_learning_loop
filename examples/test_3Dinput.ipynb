# %% [markdown]
# # Test with 3-D input

# %%
import sys, os
# get the parent directory of this notebook
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)
from learning_loop.active_learning import active_learning_loop
# 
import numpy as np
import plotly.graph_objects as go
from scipy.optimize import minimize_scalar
from scipy.optimize import differential_evolution

# %%
def f(x):
    """
    3D nonlinear function with a global minimum near (0.3, 0.6, 0.9).
    x is expected to be an array-like of shape (3,)
    """
    x = np.asarray(x)
    return (x[0] - 0.3)**2 + (x[1] - 0.6)**2 + (x[2] - 0.9)**2 \
           + 0.5 * np.sin(5 * x[0]) * np.cos(3 * x[1])
X = np.random.rand(1000000, 3)
Y = np.array([f(x) for x in X])
idx = np.argmin(Y)
print("Brute Force with random search:", X[idx], Y[idx])
#
bounds = [(0,1), (0,1), (0,1)]  # 3-D box
result = differential_evolution(f, bounds, seed=42, polish=True)
print("Global minimum via differential_evolution:")
print(f"  x* = {result.x}")
print(f"  f(x*) = {result.fun:.6f}")
# Out:
# Brute Force with random search: [0.31189479 0.90555981 0.89792226] -0.36199545532496846
# Global minimum via differential_evolution:
#   x* = [0.31204695 0.90674098 0.89999995]
#   f(x*) = -0.362004

# %%
X0 = np.array([[0.1, 0.1, 0.1]])        # initial single observation
Y0 = np.array([f(X0[0])])               # corresponding function value
# Candidate pool:  1000 random samples in [0,1]^3
X_grid = np.random.rand(1000, 3)
# Neural network configuration
nn_cfg = {
    "hidden_layers": [64, 32, 16],
    "activation": "relu",     # try "tanh" for smoother landscapes
    "dropout": 0.1,
    "epochs": 300,
    "lr": 1e-3,
}
# active learning loop
X_obs, Y_obs, history, cache = active_learning_loop(
    f=f,
    X_obs=X0,
    Y_obs=Y0,
    X_grid=X_grid,
    n_iters=100,
    M=8,                      # ensemble size
    model_type="nn",
    nn_config=nn_cfg,
    bootstrap=False,            # helps uncertainty early on
    acquisition="LCB",          # try "LCB" too for comparison
    patience=50,
    min_improve_pct=0.001,      # run until all candidates evaluated
)

# retrieve data for plotting
iters = np.arange(len(history))
y_next = np.array([h[2] for h in history])   # Y values evaluated each iteration
best_y = np.array([h[3] for h in history])   # running best values
best_final = np.min(best_y)
#
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=iters + 1, y=y_next,
    mode='lines+markers',
    name='Y evaluated',
    line=dict(color='royalblue', width=2),
    marker=dict(size=6)
))
fig.add_hline(
    y=result.fun,
    line_dash='dot',
    line_color='green',
    annotation_text=f"Final Best Y = {result.fun:.4f}",
    annotation_position='top right'
)
fig.update_layout(
    title="Active Learning Convergence (Neural Network)",
    xaxis_title="Iteration number",
    yaxis_title="Objective value (Y)",
    hovermode="x unified",
    template="plotly_white",
    width=800,
    height=500
)
fig.show()
# Out:
# Starting active learning run — initial best_y = 1.1590
# [001/100] acq=LCB, x_next=[0.7888, 0.0128, 0.0305], y_next=0.9804 (new), best_y=0.9804
# [002/100] acq=LCB, x_next=[0.9465, 0.0022, 0.0519], y_next=0.9947 (new), best_y=0.9804
# [003/100] acq=LCB, x_next=[0.892 , 0.0609, 0.021 ], y_next=0.9376 (new), best_y=0.9376
# [004/100] acq=LCB, x_next=[0.9642, 0.0521, 0.0863], y_next=0.9125 (new), best_y=0.9125
# [005/100] acq=LCB, x_next=[0.8463, 0.0717, 0.0566], y_next=0.8558 (new), best_y=0.8558
# [006/100] acq=LCB, x_next=[0.7531, 0.8106, 0.1546], y_next=1.0268 (new), best_y=0.8558
# [007/100] acq=LCB, x_next=[0.7667, 0.3465, 0.0127], y_next=0.9078 (new), best_y=0.8558
# [008/100] acq=LCB, x_next=[0.7014, 0.2803, 0.0007], y_next=0.9530 (new), best_y=0.8558
# [009/100] acq=LCB, x_next=[0.9471, 0.2141, 0.0046], y_next=0.9690 (new), best_y=0.8558
# [010/100] acq=LCB, x_next=[0.6988, 0.2678, 0.0264], y_next=0.9128 (new), best_y=0.8558
# [011/100] acq=LCB, x_next=[0.657 , 0.2498, 0.0342], y_next=0.9474 (new), best_y=0.8558
# [012/100] acq=LCB, x_next=[0.7903, 0.1009, 0.0914], y_next=0.7977 (new), best_y=0.7977
# [013/100] acq=LCB, x_next=[0.8142, 0.2303, 0.1811], y_next=0.6092 (new), best_y=0.6092
# [014/100] acq=LCB, x_next=[0.5885, 0.2102, 0.589 ], y_next=0.4118 (new), best_y=0.4118
# [015/100] acq=LCB, x_next=[0.3888, 0.1863, 0.9779], y_next=0.5798 (new), best_y=0.4118
# [016/100] acq=LCB, x_next=[0.927 , 0.2377, 0.9706], y_next=0.1524 (new), best_y=0.1524
# [017/100] acq=LCB, x_next=[0.9964, 0.2958, 0.9869], y_next=0.2808 (new), best_y=0.1524
# [018/100] acq=LCB, x_next=[0.9234, 0.1983, 0.9099], y_next=0.1378 (new), best_y=0.1378
# [019/100] acq=LCB, x_next=[0.884 , 0.2144, 0.9268], y_next=0.1073 (new), best_y=0.1073
# [020/100] acq=LCB, x_next=[0.9108, 0.153 , 0.9105], y_next=0.1304 (new), best_y=0.1073
# [021/100] acq=LCB, x_next=[0.9759, 0.5553, 0.9643], y_next=0.5099 (new), best_y=0.1073
# [022/100] acq=LCB, x_next=[0.9711, 0.0868, 0.8962], y_next=0.2355 (new), best_y=0.1073
# [023/100] acq=LCB, x_next=[0.9465, 0.026 , 0.8551], y_next=0.2512 (new), best_y=0.1073
# [024/100] acq=LCB, x_next=[0.8614, 0.1481, 0.8907], y_next=0.1046 (new), best_y=0.1046
# [025/100] acq=LCB, x_next=[0.8941, 0.1173, 0.8805], y_next=0.1307 (new), best_y=0.1046
# [026/100] acq=LCB, x_next=[0.9563, 0.0477, 0.8689], y_next=0.2431 (new), best_y=0.1046
# [027/100] acq=LCB, x_next=[0.8199, 0.0588, 0.9868], y_next=0.1680 (new), best_y=0.1046
# [028/100] acq=LCB, x_next=[0.8035, 0.1265, 0.8644], y_next=0.1222 (new), best_y=0.1046
# [029/100] acq=LCB, x_next=[0.7712, 0.1256, 0.8402], y_next=0.1461 (new), best_y=0.1046
# [030/100] acq=LCB, x_next=[0.9943, 0.0288, 0.8201], y_next=0.3331 (new), best_y=0.1046
# [031/100] acq=LCB, x_next=[0.7579, 0.1564, 0.8968], y_next=0.1373 (new), best_y=0.1046
# [032/100] acq=LCB, x_next=[0.7352, 0.2195, 0.9402], y_next=0.1344 (new), best_y=0.1046
# [033/100] acq=LCB, x_next=[0.668 , 0.0556, 0.9138], y_next=0.3348 (new), best_y=0.1046
# [034/100] acq=LCB, x_next=[0.8819, 0.1856, 0.8163], y_next=0.1122 (new), best_y=0.1046
# [035/100] acq=LCB, x_next=[0.7825, 0.1914, 0.7907], y_next=0.1192 (new), best_y=0.1046
# [036/100] acq=LCB, x_next=[0.8712, 0.2754, 0.8139], y_next=0.1215 (new), best_y=0.1046
# [037/100] acq=LCB, x_next=[0.7286, 0.1107, 0.7926], y_next=0.2074 (new), best_y=0.1046
# [038/100] acq=LCB, x_next=[0.9579, 0.2858, 0.8208], y_next=0.2116 (new), best_y=0.1046
# [039/100] acq=LCB, x_next=[0.7029, 0.1686, 0.8453], y_next=0.1921 (new), best_y=0.1046
# [040/100] acq=LCB, x_next=[0.7038, 0.2182, 0.8439], y_next=0.1658 (new), best_y=0.1046
# [041/100] acq=LCB, x_next=[0.8272, 0.3297, 0.9936], y_next=0.1294 (new), best_y=0.1046
# [042/100] acq=LCB, x_next=[0.9574, 0.0371, 0.7359], y_next=0.2804 (new), best_y=0.1046
# [043/100] acq=LCB, x_next=[0.7007, 0.1783, 0.77  ], y_next=0.2030 (new), best_y=0.1046
# [044/100] acq=LCB, x_next=[0.6834, 0.2186, 0.8032], y_next=0.1941 (new), best_y=0.1046
# [045/100] acq=LCB, x_next=[0.7274, 0.1335, 0.7264], y_next=0.2115 (new), best_y=0.1046
# [046/100] acq=LCB, x_next=[0.9494, 0.322 , 0.8344], y_next=0.2192 (new), best_y=0.1046
# [047/100] acq=LCB, x_next=[0.6774, 0.2388, 0.8247], y_next=0.1869 (new), best_y=0.1046
# [048/100] acq=LCB, x_next=[0.9389, 0.2884, 0.7844], y_next=0.1945 (new), best_y=0.1046
# [049/100] acq=LCB, x_next=[0.6756, 0.3788, 0.9967], y_next=0.1501 (new), best_y=0.1046
# [050/100] acq=LCB, x_next=[0.778 , 0.3456, 0.8877], y_next=0.1202 (new), best_y=0.1046
# [051/100] acq=LCB, x_next=[0.8101, 0.383 , 0.9366], y_next=0.1472 (new), best_y=0.1046
# [052/100] acq=LCB, x_next=[0.7076, 0.399 , 0.976 ], y_next=0.1418 (new), best_y=0.1046
# [053/100] acq=LCB, x_next=[0.6884, 0.3089, 0.7957], y_next=0.1576 (new), best_y=0.1046
# [054/100] acq=LCB, x_next=[0.7347, 0.3474, 0.8295], y_next=0.1299 (new), best_y=0.1046
# [055/100] acq=LCB, x_next=[0.7585, 0.3709, 0.8493], y_next=0.1313 (new), best_y=0.1046
# [056/100] acq=LCB, x_next=[0.7736, 0.2626, 0.7164], y_next=0.1376 (new), best_y=0.1046
# [057/100] acq=LCB, x_next=[0.6321, 0.3526, 0.8755], y_next=0.1674 (new), best_y=0.1046
# [058/100] acq=LCB, x_next=[0.6187, 0.3452, 0.9296], y_next=0.1796 (new), best_y=0.1046
# [059/100] acq=LCB, x_next=[0.615 , 0.4147, 0.8907], y_next=0.1443 (new), best_y=0.1046
# [060/100] acq=LCB, x_next=[0.8573, 0.3985, 0.8267], y_next=0.1896 (new), best_y=0.1046
# [061/100] acq=LCB, x_next=[0.7529, 0.4014, 0.8116], y_next=0.1478 (new), best_y=0.1046
# [062/100] acq=LCB, x_next=[0.7959, 0.4943, 0.9472], y_next=0.2266 (new), best_y=0.1046
# [063/100] acq=LCB, x_next=[0.6177, 0.2594, 0.8077], y_next=0.2444 (new), best_y=0.1046
# [064/100] acq=LCB, x_next=[0.5958, 0.3546, 0.8391], y_next=0.1907 (new), best_y=0.1046
# [065/100] acq=LCB, x_next=[0.6169, 0.5027, 0.9651], y_next=0.1159 (new), best_y=0.1046
# [066/100] acq=LCB, x_next=[0.5688, 0.3993, 0.8599], y_next=0.1675 (new), best_y=0.1046
# [067/100] acq=LCB, x_next=[0.628 , 0.5113, 0.8983], y_next=0.1155 (new), best_y=0.1046
# [068/100] acq=LCB, x_next=[0.9696, 0.8121, 0.9638], y_next=0.8747 (new), best_y=0.1046
# [069/100] acq=LCB, x_next=[0.5825, 0.4825, 0.8484], y_next=0.1102 (new), best_y=0.1046
# [070/100] acq=LCB, x_next=[0.7619, 0.2154, 0.6772], y_next=0.1637 (new), best_y=0.1046
# [071/100] acq=LCB, x_next=[0.5187, 0.4155, 0.8927], y_next=0.1650 (new), best_y=0.1046
# [072/100] acq=LCB, x_next=[0.5264, 0.5212, 0.9137], y_next=0.0594 (new), best_y=0.0594
# [073/100] acq=LCB, x_next=[0.5512, 0.424 , 0.7487], y_next=0.1723 (new), best_y=0.0594
# [074/100] acq=LCB, x_next=[0.5377, 0.3424, 0.8568], y_next=0.2379 (new), best_y=0.0594
# [075/100] acq=LCB, x_next=[0.6852, 0.4044, 0.7135], y_next=0.1723 (new), best_y=0.0594
# [076/100] acq=LCB, x_next=[0.6048, 0.6017, 0.9923], y_next=0.0878 (new), best_y=0.0594
# [077/100] acq=LCB, x_next=[0.4332, 0.6231, 0.9599], y_next=-0.0999 (new), best_y=-0.0999
# [078/100] acq=LCB, x_next=[0.4063, 0.6745, 0.9487], y_next=-0.1767 (new), best_y=-0.1767
# [079/100] acq=LCB, x_next=[0.3069, 0.8293, 0.9766], y_next=-0.3382 (new), best_y=-0.3382
# [080/100] acq=LCB, x_next=[0.0456, 0.9624, 0.822 ], y_next=0.0926 (new), best_y=-0.3382
# [081/100] acq=LCB, x_next=[0.2257, 0.9419, 0.995 ], y_next=-0.2981 (new), best_y=-0.3382
# [082/100] acq=LCB, x_next=[0.1741, 0.898 , 0.9929], y_next=-0.2314 (new), best_y=-0.3382
# [083/100] acq=LCB, x_next=[0.2784, 0.9447, 0.9947], y_next=-0.3407 (new), best_y=-0.3407
# [084/100] acq=LCB, x_next=[0.1708, 0.8451, 0.969 ], y_next=-0.2282 (new), best_y=-0.3407
# [085/100] acq=LCB, x_next=[0.0671, 0.8739, 0.9588], y_next=-0.0102 (new), best_y=-0.3407
# [086/100] acq=LCB, x_next=[0.2669, 0.8547, 0.9196], y_next=-0.3409 (new), best_y=-0.3409
# [087/100] acq=LCB, x_next=[0.2585, 0.8011, 0.9434], y_next=-0.3115 (new), best_y=-0.3409
# [088/100] acq=LCB, x_next=[0.2675, 0.8769, 0.8952], y_next=-0.3466 (new), best_y=-0.3466
# [089/100] acq=LCB, x_next=[0.141 , 0.8544, 0.9479], y_next=-0.1790 (new), best_y=-0.3466
# [090/100] acq=LCB, x_next=[0.3401, 0.8799, 0.8874], y_next=-0.3545 (new), best_y=-0.3545
# [091/100] acq=LCB, x_next=[0.3137, 0.9812, 0.8823], y_next=-0.3444 (new), best_y=-0.3545
# [092/100] acq=LCB, x_next=[0.3906, 0.942 , 0.9227], y_next=-0.3154 (new), best_y=-0.3545
# [093/100] acq=LCB, x_next=[0.4096, 0.903 , 0.9285], y_next=-0.2986 (new), best_y=-0.3545
# [094/100] acq=LCB, x_next=[0.3972, 0.8776, 0.8815], y_next=-0.3128 (new), best_y=-0.3545
# [095/100] acq=LCB, x_next=[0.469 , 0.8993, 0.956 ], y_next=-0.2016 (new), best_y=-0.3545
# [096/100] acq=LCB, x_next=[0.3521, 0.9227, 0.8156], y_next=-0.3432 (new), best_y=-0.3545
# [097/100] acq=LCB, x_next=[0.3471, 0.8352, 0.8367], y_next=-0.3353 (new), best_y=-0.3545
# [098/100] acq=LCB, x_next=[0.3653, 0.9224, 0.8114], y_next=-0.3342 (new), best_y=-0.3545
# [099/100] acq=LCB, x_next=[0.4659, 0.9408, 0.8967], y_next=-0.2009 (new), best_y=-0.3545
# [100/100] acq=LCB, x_next=[0.3359, 0.9349, 0.7478], y_next=-0.3325 (new), best_y=-0.3545

# %%
X0 = np.array([[0.1, 0.1, 0.1]])        # initial single observation
Y0 = np.array([f(X0[0])])               # corresponding function value
# Candidate pool:  1000 random samples in [0,1]^3
X_grid = np.random.rand(1000, 3)
# active learning loop
X_obs, Y_obs, history, cache = active_learning_loop(
    f=f,
    X_obs=X0,
    Y_obs=Y0,
    X_grid=X_grid,
    n_iters=200,
    M=8,                      # ensemble size
    model_type="poly",
    bootstrap=False,            # helps uncertainty early on
    acquisition="LCB",          # try "LCB" too for comparison
    patience=50,
    min_improve_pct=0.001,      # run until all candidates evaluated
)

# retrieve data for plotting
iters = np.arange(len(history))
y_next = np.array([h[2] for h in history])   # Y values evaluated each iteration
best_y = np.array([h[3] for h in history])   # running best values
best_final = np.min(best_y)
#
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=iters + 1, y=y_next,
    mode='lines+markers',
    name='Y evaluated',
    line=dict(color='royalblue', width=2),
    marker=dict(size=6)
))
fig.add_hline(
    y=result.fun,
    line_dash='dot',
    line_color='green',
    annotation_text=f"Final Best Y = {result.fun:.4f}",
    annotation_position='top right'
)
fig.update_layout(
    title="Active Learning Convergence (Polynomial)",
    xaxis_title="Iteration number",
    yaxis_title="Objective value (Y)",
    hovermode="x unified",
    template="plotly_white",
    width=800,
    height=500
)
fig.show()
# Out:
# Starting active learning run — initial best_y = 1.1590
# [001/200] acq=LCB, x_next=[0.8925, 0.2842, 0.0174], y_next=0.9110 (new), best_y=0.9110
# [002/200] acq=LCB, x_next=[0.9902, 0.8944, 0.0503], y_next=1.7207 (new), best_y=0.9110
# [003/200] acq=LCB, x_next=[0.9912, 0.0063, 0.3705], y_next=0.6254 (new), best_y=0.6254
# [004/200] acq=LCB, x_next=[0.9645, 0.0205, 0.7924], y_next=0.2930 (new), best_y=0.2930
# [005/200] acq=LCB, x_next=[0.9435, 0.1009, 0.9513], y_next=0.1885 (new), best_y=0.1885
# [006/200] acq=LCB, x_next=[0.9035, 0.0678, 0.9485], y_next=0.1694 (new), best_y=0.1694
# [007/200] acq=LCB, x_next=[0.7326, 0.0201, 0.9903], y_next=0.2830 (new), best_y=0.1694
# [008/200] acq=LCB, x_next=[0.907 , 0.0615, 0.9099], y_next=0.1747 (new), best_y=0.1694
# [009/200] acq=LCB, x_next=[0.8234, 0.8026, 0.9815], y_next=0.6291 (new), best_y=0.1694
# [010/200] acq=LCB, x_next=[0.8121, 0.2116, 0.8618], y_next=0.0945 (new), best_y=0.0945
# [011/200] acq=LCB, x_next=[0.7834, 0.3009, 0.9635], y_next=0.1103 (new), best_y=0.0945
# [012/200] acq=LCB, x_next=[0.772 , 0.3439, 0.842 ], y_next=0.1228 (new), best_y=0.0945
# [013/200] acq=LCB, x_next=[0.7612, 0.2388, 0.8116], y_next=0.1185 (new), best_y=0.0945
# [014/200] acq=LCB, x_next=[0.8532, 0.135 , 0.7887], y_next=0.1201 (new), best_y=0.0945
# [015/200] acq=LCB, x_next=[0.7609, 0.2537, 0.7008], y_next=0.1492 (new), best_y=0.0945
# [016/200] acq=LCB, x_next=[0.8859, 0.0975, 0.9497], y_next=0.1386 (new), best_y=0.0945
# [017/200] acq=LCB, x_next=[0.7632, 0.1151, 0.8863], y_next=0.1561 (new), best_y=0.0945
# [018/200] acq=LCB, x_next=[0.1006, 0.9871, 0.9202], y_next=-0.0472 (new), best_y=-0.0472
# [019/200] acq=LCB, x_next=[0.3099, 0.9921, 0.7572], y_next=-0.3188 (new), best_y=-0.3188
# [020/200] acq=LCB, x_next=[0.3321, 0.9966, 0.5196], y_next=-0.1892 (new), best_y=-0.3188
# [021/200] acq=LCB, x_next=[0.3928, 0.9754, 0.9716], y_next=-0.2965 (new), best_y=-0.3188
# [022/200] acq=LCB, x_next=[0.4081, 0.9644, 0.9324], y_next=-0.2866 (new), best_y=-0.3188
# [023/200] acq=LCB, x_next=[0.5433, 0.9671, 0.8436], y_next=-0.0031 (new), best_y=-0.3188
# [024/200] acq=LCB, x_next=[0.1335, 0.9772, 0.0672], y_next=0.5610 (new), best_y=-0.3188
# [025/200] acq=LCB, x_next=[0.2352, 0.9392, 0.7501], y_next=-0.2958 (new), best_y=-0.3188
# [026/200] acq=LCB, x_next=[0.2949, 0.9421, 0.8374], y_next=-0.3522 (new), best_y=-0.3522
# [027/200] acq=LCB, x_next=[0.3618, 0.9347, 0.815 ], y_next=-0.3354 (new), best_y=-0.3522
# [028/200] acq=LCB, x_next=[0.317 , 0.9212, 0.6812], y_next=-0.3133 (new), best_y=-0.3522
# [029/200] acq=LCB, x_next=[0.2447, 0.8997, 0.8327], y_next=-0.3274 (new), best_y=-0.3522
# [030/200] acq=LCB, x_next=[0.1925, 0.9062, 0.9473], y_next=-0.2666 (new), best_y=-0.3522
# [031/200] acq=LCB, x_next=[0.3275, 0.8498, 0.7109], y_next=-0.3150 (new), best_y=-0.3522
# [032/200] acq=LCB, x_next=[0.9925, 0.3746, 0.4822], y_next=0.4956 (new), best_y=-0.3522
# [033/200] acq=LCB, x_next=[0.5389, 0.9463, 0.0252], y_next=0.7360 (new), best_y=-0.3522
# [034/200] acq=LCB, x_next=[0.557 , 0.1306, 0.0087], y_next=1.2423 (new), best_y=-0.3522
# [035/200] acq=LCB, x_next=[0.0298, 0.5885, 0.3079], y_next=0.4093 (new), best_y=-0.3522
# [036/200] acq=LCB, x_next=[0.2276, 0.8488, 0.6702], y_next=-0.2559 (new), best_y=-0.3522
# [037/200] acq=LCB, x_next=[0.2937, 0.8146, 0.8949], y_next=-0.3350 (new), best_y=-0.3522
# [038/200] acq=LCB, x_next=[0.4004, 0.7501, 0.9283], y_next=-0.2520 (new), best_y=-0.3522
# [039/200] acq=LCB, x_next=[0.3575, 0.7245, 0.8714], y_next=-0.2572 (new), best_y=-0.3522
# [040/200] acq=LCB, x_next=[0.0058, 0.8411, 0.2471], y_next=0.5592 (new), best_y=-0.3522
# [041/200] acq=LCB, x_next=[0.1356, 0.3574, 0.0205], y_next=1.0093 (new), best_y=-0.3522
# [042/200] acq=LCB, x_next=[0.93  , 0.9279, 0.6523], y_next=1.0331 (new), best_y=-0.3522
# [043/200] acq=LCB, x_next=[0.9975, 0.5237, 0.8365], y_next=0.4965 (new), best_y=-0.3522
# [044/200] acq=LCB, x_next=[0.3026, 0.8934, 0.6052], y_next=-0.2740 (new), best_y=-0.3522
# [045/200] acq=LCB, x_next=[0.282 , 0.9608, 0.0508], y_next=0.3746 (new), best_y=-0.3522
# [046/200] acq=LCB, x_next=[0.3075, 0.5164, 0.231 ], y_next=0.4654 (new), best_y=-0.3522
# [047/200] acq=LCB, x_next=[0.9151, 0.0588, 0.0349], y_next=0.9321 (new), best_y=-0.3522
# [048/200] acq=LCB, x_next=[0.165 , 0.9991, 0.329 ], y_next=0.1402 (new), best_y=-0.3522
# [049/200] acq=LCB, x_next=[7.7593e-04, 5.8655e-01, 9.2532e-01], y_next=0.0900 (new), best_y=-0.3522
# [050/200] acq=LCB, x_next=[0.8796, 0.9711, 0.1239], y_next=1.5391 (new), best_y=-0.3522
# [051/200] acq=LCB, x_next=[0.0611, 0.0222, 0.4512], y_next=0.7423 (new), best_y=-0.3522
# [052/200] acq=LCB, x_next=[0.2553, 0.0013, 0.2843], y_next=1.2180 (new), best_y=-0.3522
# [053/200] acq=LCB, x_next=[0.0237, 0.4263, 0.5527], y_next=0.2441 (new), best_y=-0.3522
# [054/200] acq=LCB, x_next=[0.0764, 0.0077, 0.0767], y_next=1.2648 (new), best_y=-0.3522
# [055/200] acq=LCB, x_next=[0.99  , 0.1653, 0.0238], y_next=1.0054 (new), best_y=-0.3522
# [056/200] acq=LCB, x_next=[0.0088, 0.1137, 0.9693], y_next=0.3469 (new), best_y=-0.3522
# [057/200] acq=LCB, x_next=[0.2408, 0.7727, 0.8817], y_next=-0.2836 (new), best_y=-0.3522
# [058/200] acq=LCB, x_next=[0.4285, 0.9032, 0.8208], y_next=-0.2672 (new), best_y=-0.3522
# [059/200] acq=LCB, x_next=[0.422 , 0.8169, 0.8387], y_next=-0.2649 (new), best_y=-0.3522
# [060/200] acq=LCB, x_next=[0.1873, 0.8112, 0.9092], y_next=-0.2485 (new), best_y=-0.3522
# [061/200] acq=LCB, x_next=[0.0307, 0.233 , 0.8336], y_next=0.2700 (new), best_y=-0.3522
# [062/200] acq=LCB, x_next=[0.275 , 0.7528, 0.7743], y_next=-0.2715 (new), best_y=-0.3522
# [063/200] acq=LCB, x_next=[0.1924, 0.8246, 0.9501], y_next=-0.2575 (new), best_y=-0.3522
# [064/200] acq=LCB, x_next=[0.2832, 0.7408, 0.7397], y_next=-0.2538 (new), best_y=-0.3522
# [065/200] acq=LCB, x_next=[0.4394, 0.9338, 0.8359], y_next=-0.2469 (new), best_y=-0.3522
# [066/200] acq=LCB, x_next=[0.3793, 0.7419, 0.6946], y_next=-0.2199 (new), best_y=-0.3522
# [067/200] acq=LCB, x_next=[0.2778, 0.6802, 0.9804], y_next=-0.2092 (new), best_y=-0.3522
# [068/200] acq=LCB, x_next=[0.2114, 0.7482, 0.7683], y_next=-0.2246 (new), best_y=-0.3522
# [069/200] acq=LCB, x_next=[0.3369, 0.6876, 0.7929], y_next=-0.2141 (new), best_y=-0.3522
# [070/200] acq=LCB, x_next=[0.4521, 0.7964, 0.8711], y_next=-0.2191 (new), best_y=-0.3522
# [071/200] acq=LCB, x_next=[0.4524, 0.9296, 0.9727], y_next=-0.2243 (new), best_y=-0.3522
# [072/200] acq=LCB, x_next=[0.451 , 0.833 , 0.9956], y_next=-0.2239 (new), best_y=-0.3522
# [073/200] acq=LCB, x_next=[0.4646, 0.9141, 0.9389], y_next=-0.2090 (new), best_y=-0.3522
# [074/200] acq=LCB, x_next=[0.4637, 0.8234, 0.989 ], y_next=-0.2024 (new), best_y=-0.3522
# [075/200] acq=LCB, x_next=[0.2213, 0.8405, 0.5816], y_next=-0.1984 (new), best_y=-0.3522
# [076/200] acq=LCB, x_next=[0.1649, 0.7984, 0.7399], y_next=-0.1862 (new), best_y=-0.3522
# Stopping early: no improvement > 0.10% for 50 consecutive iterations.

# %%
X0 = np.array([[0.1, 0.1, 0.1]])        # initial single observation
Y0 = np.array([f(X0[0])])               # corresponding function value
# Candidate pool:  1000 random samples in [0,1]^3
X_grid = np.random.rand(1000, 3)
# active learning loop
X_obs, Y_obs, history, cache = active_learning_loop(
    f=f,
    X_obs=X0,
    Y_obs=Y0,
    X_grid=X_grid,
    n_iters=500,
    M=8,                      # ensemble size
    model_type="tree",
    bootstrap=False,            # helps uncertainty early on
    acquisition="EI",          # try "LCB" too for comparison
    patience=50,
    min_improve_pct=0.001,      # run until all candidates evaluated
)

# retrieve data for plotting
iters = np.arange(len(history))
y_next = np.array([h[2] for h in history])   # Y values evaluated each iteration
best_y = np.array([h[3] for h in history])   # running best values
best_final = np.min(best_y)
#
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=iters + 1, y=y_next,
    mode='lines+markers',
    name='Y evaluated',
    line=dict(color='royalblue', width=2),
    marker=dict(size=6)
))
fig.add_hline(
    y=result.fun,
    line_dash='dot',
    line_color='green',
    annotation_text=f"Final Best Y = {result.fun:.4f}",
    annotation_position='top right'
)
fig.update_layout(
    title="Active Learning Convergence (Random Forest)",
    xaxis_title="Iteration number",
    yaxis_title="Objective value (Y)",
    hovermode="x unified",
    template="plotly_white",
    width=800,
    height=500
)
fig.show()
# Out:
# Starting active learning run — initial best_y = 1.1590
# [001/500] acq=EI, x_next=[0.6397, 0.7581, 0.9229], y_next=0.1594 (new), best_y=0.1594
# [002/500] acq=EI, x_next=[0.1064, 0.9351, 0.7617], y_next=-0.0704 (new), best_y=-0.0704
# [003/500] acq=EI, x_next=[0.3098, 0.8563, 0.1389], y_next=0.2250 (new), best_y=-0.0704
# [004/500] acq=EI, x_next=[1.5006e-01, 9.7538e-01, 8.7635e-04], y_next=0.6388 (new), best_y=-0.0704
# [005/500] acq=EI, x_next=[0.3922, 0.9114, 0.3552], y_next=-0.0223 (new), best_y=-0.0704
# [006/500] acq=EI, x_next=[0.217 , 0.8894, 0.8485], y_next=-0.3002 (new), best_y=-0.3002
# [007/500] acq=EI, x_next=[0.8736, 0.9005, 0.8895], y_next=0.8452 (new), best_y=-0.3002
# [008/500] acq=EI, x_next=[0.7537, 0.9043, 0.9276], y_next=0.5658 (new), best_y=-0.3002
# [009/500] acq=EI, x_next=[0.8015, 0.4815, 0.0914], y_next=0.8715 (new), best_y=-0.3002
# [010/500] acq=EI, x_next=[0.6704, 0.9769, 0.949 ], y_next=0.3838 (new), best_y=-0.3002
# [011/500] acq=EI, x_next=[0.4779, 0.8759, 0.277 ], y_next=0.1984 (new), best_y=-0.3002
# [012/500] acq=EI, x_next=[0.6975, 0.6034, 0.9574], y_next=0.2015 (new), best_y=-0.3002
# [013/500] acq=EI, x_next=[0.2105, 0.901 , 0.3059], y_next=0.0584 (new), best_y=-0.3002
# [014/500] acq=EI, x_next=[0.194 , 0.1156, 0.8615], y_next=0.6352 (new), best_y=-0.3002
# [015/500] acq=EI, x_next=[0.206 , 0.9671, 0.8471], y_next=-0.2699 (new), best_y=-0.3002
# [016/500] acq=EI, x_next=[0.8587, 0.5911, 0.8429], y_next=0.4073 (new), best_y=-0.3002
# [017/500] acq=EI, x_next=[0.0667, 0.8626, 0.0923], y_next=0.6366 (new), best_y=-0.3002
# [018/500] acq=EI, x_next=[0.738 , 0.9325, 0.8373], y_next=0.5516 (new), best_y=-0.3002
# [019/500] acq=EI, x_next=[0.6784, 0.2086, 0.8322], y_next=0.2005 (new), best_y=-0.3002
# [020/500] acq=EI, x_next=[0.5141, 0.5516, 0.8458], y_next=0.0284 (new), best_y=-0.3002
# [021/500] acq=EI, x_next=[0.2236, 0.8309, 0.8466], y_next=-0.2962 (new), best_y=-0.3002
# [022/500] acq=EI, x_next=[0.0674, 0.8107, 0.849 ], y_next=-0.0244 (new), best_y=-0.3002
# [023/500] acq=EI, x_next=[0.6767, 0.4203, 0.8785], y_next=0.1381 (new), best_y=-0.3002
# [024/500] acq=EI, x_next=[0.0933, 0.7029, 0.8585], y_next=-0.0602 (new), best_y=-0.3002
# [025/500] acq=EI, x_next=[0.2489, 0.2399, 0.8545], y_next=0.4905 (new), best_y=-0.3002
# [026/500] acq=EI, x_next=[0.0636, 0.1645, 0.707 ], y_next=0.4205 (new), best_y=-0.3002
# [027/500] acq=EI, x_next=[0.051 , 0.7745, 0.1034], y_next=0.6409 (new), best_y=-0.3002
# [028/500] acq=EI, x_next=[0.0673, 0.1164, 0.7949], y_next=0.4542 (new), best_y=-0.3002
# [029/500] acq=EI, x_next=[0.5185, 0.9123, 0.0798], y_next=0.5781 (new), best_y=-0.3002
# [030/500] acq=EI, x_next=[0.7886, 0.2972, 0.5996], y_next=0.1950 (new), best_y=-0.3002
# [031/500] acq=EI, x_next=[0.8415, 0.3954, 0.3626], y_next=0.4598 (new), best_y=-0.3002
# [032/500] acq=EI, x_next=[0.758 , 0.7447, 0.9443], y_next=0.4185 (new), best_y=-0.3002
# [033/500] acq=EI, x_next=[0.7178, 0.7482, 0.4947], y_next=0.4957 (new), best_y=-0.3002
# [034/500] acq=EI, x_next=[0.8138, 0.9299, 0.3882], y_next=1.0102 (new), best_y=-0.3002
# [035/500] acq=EI, x_next=[0.784 , 0.9652, 0.8959], y_next=0.7081 (new), best_y=-0.3002
# [036/500] acq=EI, x_next=[0.7821, 0.8664, 0.8416], y_next=0.6046 (new), best_y=-0.3002
# [037/500] acq=EI, x_next=[0.7923, 0.8832, 0.8631], y_next=0.6460 (new), best_y=-0.3002
# [038/500] acq=EI, x_next=[0.8248, 0.8287, 0.5254], y_next=0.7977 (new), best_y=-0.3002
# [039/500] acq=EI, x_next=[0.8117, 0.8809, 0.6955], y_next=0.7310 (new), best_y=-0.3002
# [040/500] acq=EI, x_next=[0.8358, 0.7922, 0.0347], y_next=1.3833 (new), best_y=-0.3002
# [041/500] acq=EI, x_next=[0.8595, 0.9186, 0.5171], y_next=0.9852 (new), best_y=-0.3002
# [042/500] acq=EI, x_next=[0.9455, 0.9462, 0.7666], y_next=1.0314 (new), best_y=-0.3002
# [043/500] acq=EI, x_next=[0.9798, 0.9777, 0.8575], y_next=1.0873 (new), best_y=-0.3002
# [044/500] acq=EI, x_next=[0.8257, 0.8527, 0.672 ], y_next=0.7402 (new), best_y=-0.3002
# [045/500] acq=EI, x_next=[0.929 , 0.9039, 0.5941], y_next=1.0351 (new), best_y=-0.3002
# [046/500] acq=EI, x_next=[0.8879, 0.5181, 0.2114], y_next=0.8185 (new), best_y=-0.3002
# [047/500] acq=EI, x_next=[0.9674, 0.916 , 0.2174], y_next=1.4694 (new), best_y=-0.3002
# [048/500] acq=EI, x_next=[0.8715, 0.9657, 0.3695], y_next=1.1966 (new), best_y=-0.3002
# [049/500] acq=EI, x_next=[0.9255, 0.9673, 0.8318], y_next=1.0148 (new), best_y=-0.3002
# [050/500] acq=EI, x_next=[0.9789, 0.9686, 0.7349], y_next=1.1021 (new), best_y=-0.3002
# [051/500] acq=EI, x_next=[0.9525, 0.9883, 0.7272], y_next=1.0980 (new), best_y=-0.3002
# [052/500] acq=EI, x_next=[0.6494, 0.4864, 0.4977], y_next=0.2909 (new), best_y=-0.3002
# [053/500] acq=EI, x_next=[0.8918, 0.1145, 0.2484], y_next=0.5548 (new), best_y=-0.3002
# [054/500] acq=EI, x_next=[0.9801, 0.2873, 0.1238], y_next=0.8431 (new), best_y=-0.3002
# [055/500] acq=EI, x_next=[0.1548, 0.3632, 0.9656], y_next=0.2433 (new), best_y=-0.3002
# [056/500] acq=EI, x_next=[0.5742, 0.2143, 0.8458], y_next=0.3338 (new), best_y=-0.3002
# Stopping early: no improvement > 0.10% for 50 consecutive iterations.
